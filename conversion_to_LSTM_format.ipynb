# %%
X0=[]
X1=[]
X2=[]
X3=[]
X4=[]
X5=[]
X6=[]
X7=[]
X7=[]
X8 = []
X9 = []
X10= []
X11= []
X12= []
X13= []
X14= []
X15= []
X16= []
X17= []
X18= []
X19= []
X20= []
X21= []
X22= []
X23= []
X24= []
X25= []
X26= []
X27= []
X28= []
X29= []
X30= []
X31= []
y=[]

for i in range (0, train.shape[0]):       #df.shape[0]-number_of_days
    X0.append(train.iloc[i, 3])
    X1.append(train.iloc[i, 4])
    X2.append(train.iloc[i, 5])
    X3.append(train.iloc[i, 6])
    X4.append(train.iloc[i, 7])
    X5.append(train.iloc[i, 8])
    X6.append(train.iloc[i, 9])
    X7.append(train.iloc[i, 10])
    X8.append(train.iloc[i, 11])
    X9.append(train.iloc[i, 12])
    X10.append(train.iloc[i, 13])
    X11.append(train.iloc[i, 14])
    X12.append(train.iloc[i, 15])
    X13.append(train.iloc[i, 16])
    X14.append(train.iloc[i, 17])
    X15.append(train.iloc[i, 18])
    X16.append(train.iloc[i, 19])
    X17.append(train.iloc[i, 20])
    X18.append(train.iloc[i, 21])
    X19.append(train.iloc[i, 22])
    X20.append(train.iloc[i, 23])
    X21.append(train.iloc[i, 24])
    X22.append(train.iloc[i, 25])
    X23.append(train.iloc[i, 26])
    X24.append(train.iloc[i, 27])
    X25.append(train.iloc[i, 28])
    X26.append(train.iloc[i, 29])
    X27.append(train.iloc[i, 30])
    X28.append(train.iloc[i, 31])
    X29.append(train.iloc[i, 32])
    X30.append(train.iloc[i, 33])
    X31.append(train.iloc[i, 34])

    y.append(train.iloc[i, 35])
    
    # print(f"{i}/{len(train)}")
    

X0, X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X12, X13, X14, X15, X16, X17, X18, X19, X20, X21, X22, X23, X24, X25, X26, X27, X28, X29, X30, X31, y = np.array(X0), np.array(X1), np.array(X2), np.array(X3), np.array(X4), np.array(X5), np.array(X6), np.array(X7), np.array(X8), np.array(X9), np.array(X10), np.array(X11), np.array(X12), np.array(X13), np.array(X14), np.array(X15), np.array(X16), np.array(X17), np.array(X18), np.array(X19), np.array(X20), np.array(X21), np.array(X22), np.array(X23), np.array(X24), np.array(X25), np.array(X26), np.array(X27), np.array(X28), np.array(X29), np.array(X30), np.array(X31), np.array(y)


X0 = np.reshape(X0, (len(X0), 1))
X1 = np.reshape(X1, (len(X1), 1))
X2 = np.reshape(X2, (len(X2), 1))
X3 = np.reshape(X3, (len(X3), 1))
X4 = np.reshape(X4, (len(X4), 1))
X5 = np.reshape(X5, (len(X5), 1))
X6 = np.reshape(X6, (len(X6), 1))
X7 = np.reshape(X7, (len(X7), 1))
X8 = np.reshape(X8, (len(X8), 1))
X9 = np.reshape(X9, (len(X9), 1))
X10 = np.reshape(X10, (len(X10), 1))
X11 = np.reshape(X11, (len(X11), 1))
X12 = np.reshape(X12, (len(X12), 1))
X13 = np.reshape(X13, (len(X13), 1))
X14 = np.reshape(X14, (len(X14), 1))
X15 = np.reshape(X15, (len(X15), 1))
X16 = np.reshape(X16, (len(X16), 1))
X17 = np.reshape(X17, (len(X17), 1))
X18 = np.reshape(X18, (len(X18), 1))
X19 = np.reshape(X19, (len(X19), 1))
X20 = np.reshape(X20, (len(X20), 1))
X21 = np.reshape(X21, (len(X21), 1))
X22 = np.reshape(X22, (len(X22), 1))
X23 = np.reshape(X23, (len(X23), 1))
X24 = np.reshape(X24, (len(X24), 1))
X25 = np.reshape(X25, (len(X25), 1))
X26 = np.reshape(X26, (len(X26), 1))
X27 = np.reshape(X27, (len(X27), 1))
X28 = np.reshape(X28, (len(X28), 1))
X29 = np.reshape(X29, (len(X29), 1))
X30 = np.reshape(X30, (len(X30), 1))
X31 = np.reshape(X31, (len(X31), 1))
y=np.reshape(y, (len(y),1))


y_train=np.reshape(y, (len(y),1))
print("y shape is: ", y_train.shape)
X_train = np.stack([X0, X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X12, X13, X14, X15, X16, X17, X18, X19, X20, X21, X22, X23, X24, X25, X26, X27, X28, X29, X30, X31], axis=2)
print("X shape is: ", X_train.shape)

# %%
X0=[]
X1=[]
X2=[]
X3=[]
X4=[]
X5=[]
X6=[]
X7=[]
X7=[]
X8 = []
X9 = []
X10= []
X11= []
X12= []
X13= []
X14= []
X15= []
X16= []
X17= []
X18= []
X19= []
X20= []
X21= []
X22= []
X23= []
X24= []
X25= []
X26= []
X27= []
X28= []
X29= []
X30= []
X31= []
y=[]

for i in range (0, test.shape[0]):       #df.shape[0]-number_of_days
    X0.append(test.iloc[i, 3])
    X1.append(test.iloc[i, 4])
    X2.append(test.iloc[i, 5])
    X3.append(test.iloc[i, 6])
    X4.append(test.iloc[i, 7])
    X5.append(test.iloc[i, 8])
    X6.append(test.iloc[i, 9])
    X7.append(test.iloc[i, 10])
    X8.append(test.iloc[i, 11])
    X9.append(test.iloc[i, 12])
    X10.append(test.iloc[i, 13])
    X11.append(test.iloc[i, 14])
    X12.append(test.iloc[i, 15])
    X13.append(test.iloc[i, 16])
    X14.append(test.iloc[i, 17])
    X15.append(test.iloc[i, 18])
    X16.append(test.iloc[i, 19])
    X17.append(test.iloc[i, 20])
    X18.append(test.iloc[i, 21])
    X19.append(test.iloc[i, 22])
    X20.append(test.iloc[i, 23])
    X21.append(test.iloc[i, 24])
    X22.append(test.iloc[i, 25])
    X23.append(test.iloc[i, 26])
    X24.append(test.iloc[i, 27])
    X25.append(test.iloc[i, 28])
    X26.append(test.iloc[i, 29])
    X27.append(test.iloc[i, 30])
    X28.append(test.iloc[i, 31])
    X29.append(test.iloc[i, 32])
    X30.append(test.iloc[i, 33])
    X31.append(test.iloc[i, 34])

    y.append(test.iloc[i, 35])
    
    # print(f"{i}/{len(test)}")
    

X0, X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X12, X13, X14, X15, X16, X17, X18, X19, X20, X21, X22, X23, X24, X25, X26, X27, X28, X29, X30, X31, y = np.array(X0), np.array(X1), np.array(X2), np.array(X3), np.array(X4), np.array(X5), np.array(X6), np.array(X7), np.array(X8), np.array(X9), np.array(X10), np.array(X11), np.array(X12), np.array(X13), np.array(X14), np.array(X15), np.array(X16), np.array(X17), np.array(X18), np.array(X19), np.array(X20), np.array(X21), np.array(X22), np.array(X23), np.array(X24), np.array(X25), np.array(X26), np.array(X27), np.array(X28), np.array(X29), np.array(X30), np.array(X31), np.array(y)


X0 = np.reshape(X0, (len(X0), 1))
X1 = np.reshape(X1, (len(X1), 1))
X2 = np.reshape(X2, (len(X2), 1))
X3 = np.reshape(X3, (len(X3), 1))
X4 = np.reshape(X4, (len(X4), 1))
X5 = np.reshape(X5, (len(X5), 1))
X6 = np.reshape(X6, (len(X6), 1))
X7 = np.reshape(X7, (len(X7), 1))
X8 = np.reshape(X8, (len(X8), 1))
X9 = np.reshape(X9, (len(X9), 1))
X10 = np.reshape(X10, (len(X10), 1))
X11 = np.reshape(X11, (len(X11), 1))
X12 = np.reshape(X12, (len(X12), 1))
X13 = np.reshape(X13, (len(X13), 1))
X14 = np.reshape(X14, (len(X14), 1))
X15 = np.reshape(X15, (len(X15), 1))
X16 = np.reshape(X16, (len(X16), 1))
X17 = np.reshape(X17, (len(X17), 1))
X18 = np.reshape(X18, (len(X18), 1))
X19 = np.reshape(X19, (len(X19), 1))
X20 = np.reshape(X20, (len(X20), 1))
X21 = np.reshape(X21, (len(X21), 1))
X22 = np.reshape(X22, (len(X22), 1))
X23 = np.reshape(X23, (len(X23), 1))
X24 = np.reshape(X24, (len(X24), 1))
X25 = np.reshape(X25, (len(X25), 1))
X26 = np.reshape(X26, (len(X26), 1))
X27 = np.reshape(X27, (len(X27), 1))
X28 = np.reshape(X28, (len(X28), 1))
X29 = np.reshape(X29, (len(X29), 1))
X30 = np.reshape(X30, (len(X30), 1))
X31 = np.reshape(X31, (len(X31), 1))
y=np.reshape(y, (len(y),1))


y_test=np.reshape(y, (len(y),1))
print("y shape is: ", y_test.shape)
X_test = np.stack([X0, X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X12, X13, X14, X15, X16, X17, X18, X19, X20, X21, X22, X23, X24, X25, X26, X27, X28, X29, X30, X31], axis=2)
print("X shape is: ", X_test.shape)
